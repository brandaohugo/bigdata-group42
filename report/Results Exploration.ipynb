# %%
import pandas as pd

# %%
results = pd.read_csv('output.csv')

# %% [markdown]
# SELECT u.DisplayName, b.Name FROM users as u, badges as b WHERE b.id = u.id LIMIT {};

# %%
_ = results.plot(x='results', y=['std','mean'], title='Time to run query by number of results')
